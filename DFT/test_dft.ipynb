# %%
from DFT_v1 import *
import numpy as np
import matplotlib.pyplot as plt

# %%
def f1(t,w):
    return 10*np.sin(t*w)+2*np.cos(3*w*t)+np.sin(5*w*t)

# %%
def

# %%
signal_data=np.zeros(100)
w=np.pi*2/len(signal_data)
for i in range(len(signal_data)):
    signal_data[i]=f1(i,10)

# %%
plt.plot(np.arange(len(signal_data))*10,signal_data)

# %%
test=fourrier_transform(signal_data)
test.DFT()

# %%
test.plot()
# Out:
# No handles with labels found to put in legend.
